# %% [markdown]
# <a href="https://colab.research.google.com/github/GiliardGodoi/bioinfo-sars-cov2-datasets/blob/main/EstudoCaso_1_SarsCov2_FeatureExtraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória das Características Extraídas
#
# Os dados podem ser obtidos diretamente de:
# https://github.com/GiliardGodoi/bioinfo-sars-cov2-datasets

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

import os
from os import path

# %%
color_map = sns.diverging_palette(250, 15, s=80, l=40, n=11, center="light", as_cmap=True)
sns.palplot(sns.diverging_palette(250, 15, s=80, l=40, n=11, center="light",))

# %%
base = "/content/drive/Shared drives/PPGI_GILIARD/FeatureExtraction_SARS-CoV-2"
features = "/content/drive/Shared drives/PPGI_GILIARD/FeatureExtraction_SARS-CoV-2/data/processed"
# results = "/content/drive/Shared drives/PPGI_GILIARD/FeatureExtraction_SARS-CoV-2/data/results"

# %%
# Diretórios com as características extraídas.

folders = os.listdir(features)

print(folders,'\n')

folder = folders[0]

print(folder,'\n')

os.listdir(path.join(features, folder))
# Out:
# ['1-covid', '2-other-viruses']
#
# 1-covid
# ['chaos-game-theory_r4.csv',
#  'complex-network-k3l10.csv',
#  'fourier-class-r5.csv',
#  'shannon-entropy-k12.csv']

# %% [markdown]
# ## Carregando os *datasets*

# %%
df_complexNet = pd.read_csv(path.join(features, folder,'complex-network-k3l10.csv'))
df_complexNet.name = 'Complex Network Features'
print('Redes Complexas: ', df_complexNet.shape)

df_fourier = pd.read_csv(path.join(features, folder,'fourier-class-r5.csv'))
df_fourier.name = "Fourier Features"
print('Transformada Fourier', df_fourier.shape)

df_entropy = pd.read_csv(path.join(features, folder, 'shannon-entropy-k12.csv'))
df_entropy.name = "Shannon's Entropy Features"
print('Entropia (Shannon)', df_entropy.shape)

df_chaosGame = pd.read_csv(path.join(features, folder, 'chaos-game-theory_r4.csv'))
df_chaosGame.name = "Chaos Game Theory Features"
print('Teoria do Caos \ Teoria dos Jogos', df_chaosGame.shape)
# Out:
# Redes Complexas:  (1717, 122)
# Transformada Fourier (1717, 21)
# Entropia (Shannon) (1717, 14)
# Teoria do Caos \ Teoria dos Jogos (1717, 21)

# %% [markdown]
# ## Validações iniciais

# %% [markdown]
# Todos os *datasets* possuem o mesmo número de casos em cada classe?

# %%
df_complexNet[['nameseq', 'label']].groupby('label').count()
# Out:
#        nameseq
# label
# 0          403
# 1         1314

# %%
df_fourier[['nameseq', 'label']].groupby('label').count()
# Out:
#        nameseq
# label
# 0          403
# 1         1314

# %%
df_entropy[['nameseq', 'class']].groupby('class').count()
# Out:
#        nameseq
# class
# 0          403
# 1         1314

# %%
df_chaosGame[['nameseq', 'label']].groupby('label').count()
# Out:
#        nameseq
# label
# 0          403
# 1         1314

# %% [markdown]
# Existem valores que podem ser considerados como *Null* nou *NaN* nos *datasets* considerados?

# %%
# any(df_complexNet.isna())
# df_complexNet.isna().apply(any)

for df in [df_complexNet, df_chaosGame, df_entropy, df_fourier]:
  if any(df.isna().apply(any)) or any(df.isnull().apply(any)):
    print("There is something wrong with ", df.name)
  else:
    print("Everthing ok with  ", df.name)
# Out:
# Everthing ok with   Complex Network Features
# Everthing ok with   Chaos Game Theory Features
# Everthing ok with   Shannon's Entropy Features
# Everthing ok with   Fourier Features

# %%
# df_complexNet.info(verbose=True)

# %%
df_chaosGame.describe()
# Out:
#            average       median  ...     kurtosis        label
# count  1717.000000  1717.000000  ...  1717.000000  1717.000000
# mean      0.001040     0.000135  ...     0.181828     0.765288
# std       0.000459     0.000072  ...     0.013843     0.423942
# min       0.000666     0.000083  ...     0.138195     0.000000
# 25%       0.000924     0.000117  ...     0.182089     1.000000
# 50%       0.000926     0.000118  ...     0.186371     1.000000
# 75%       0.000945     0.000119  ...     0.188619     1.000000
# max       0.003866     0.000534  ...     0.229077     1.000000
#
# [8 rows x 20 columns]

# %%
df_fourier.describe()
# Out:
#            average       median  ...     kurtosis        label
# count  1717.000000  1717.000000  ...  1717.000000  1717.000000
# mean    447.278703     8.242957  ...     0.251011     0.765288
# std      18.638292     0.438657  ...     0.002667     0.423942
# min      31.039999     0.610511  ...     0.240694     0.000000
# 25%     448.324054     8.110478  ...     0.249090     1.000000
# 50%     449.223283     8.167770  ...     0.251060     1.000000
# 75%     449.819171     8.209404  ...     0.252882     1.000000
# max     458.526394     9.237870  ...     0.259039     1.000000
#
# [8 rows x 20 columns]

# %%
df_entropy.describe()
# Out:
#                 k1           k2  ...          k12        class
# count  1717.000000  1717.000000  ...  1717.000000  1717.000000
# mean      1.954939     3.880236  ...    14.849225     0.765288
# std       0.013608     0.027608  ...     0.149767     0.423942
# min       1.878915     3.742131  ...    11.004814     0.000000
# 25%       1.956932     3.882008  ...    14.856107     1.000000
# 50%       1.957122     3.882418  ...    14.857809     1.000000
# 75%       1.957210     3.882602  ...    14.859848     1.000000
# max       1.974950     3.926340  ...    14.899690     1.000000
#
# [8 rows x 13 columns]

# %%
# sns.pairplot(df_complexNet, hue="label", height=2.5)

# %%
# sns.pairplot(df_chaosGame.iloc[:,1:], hue="label", height=2.5)

# %%
#sns.pairplot(df_fourier, hue="label", height=2.5)

# %% [markdown]
# ## Análises das Características
#
# ### Transformada de Fourier

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1.0))

# %%
# dimensões
df_fourier.shape
# Out:
# (1717, 21)

# %%
# colunas
df_fourier.columns
# Out:
# Index(['nameseq', 'average', 'median', 'maximum', 'minimum', 'peak',
#        'none_levated_peak', 'sample_standard_deviation',
#        'population_standard_deviation', 'percentile15', 'percentile25',
#        'percentile50', 'percentile75', 'amplitude', 'variance',
#        'interquartile_range', 'semi_interquartile_range',
#        'coefficient_of_variation', 'skewness', 'kurtosis', 'label'],
#       dtype='object')

# %%
col = ['average', 'median', 'maximum', 'minimum', 'peak',
       'none_levated_peak', 'sample_standard_deviation',
       'population_standard_deviation', 'percentile15', 'percentile25',
       'percentile50', 'percentile75', 'amplitude', 'variance',
       'interquartile_range', 'semi_interquartile_range',
       'coefficient_of_variation', 'skewness', 'kurtosis' ]

X = scaler.fit_transform(df_fourier[col])

df = pd.DataFrame(X, columns=col)

df['label'] = df_fourier['label']

df.head()
# Out:
#     average    median   maximum  ...  skewness  kurtosis  label
# 0  0.869726  0.831351  0.770662  ...  0.023546  0.492294      0
# 1  0.876468  0.838082  0.781833  ...  0.022204  0.486914      0
# 2  0.876613  0.845063  0.782002  ...  0.022133  0.571278      0
# 3  0.875483  0.832059  0.780034  ...  0.022473  0.534225      0
# 4  0.872344  0.848817  0.774824  ...  0.022936  0.575654      0
#
# [5 rows x 20 columns]

# %%
df.describe()
# Out:
#            average       median  ...     kurtosis        label
# count  1717.000000  1717.000000  ...  1717.000000  1717.000000
# mean      0.973689     0.884679  ...     0.562379     0.765288
# std       0.043600     0.050845  ...     0.145404     0.423942
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.976134     0.869324  ...     0.457662     1.000000
# 50%       0.978238     0.875964  ...     0.565062     1.000000
# 75%       0.979632     0.880790  ...     0.664383     1.000000
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 20 columns]

# %%
sns.displot(data=df_fourier, x="median", hue="label", kind="kde")

# %%
col = ['average', 'median', 'population_standard_deviation', 'amplitude', 'skewness', 'kurtosis', 'label']

sns.pairplot(df[col].sample(500), hue='label')

# %%
sns.pairplot(df[col].sample(500), hue='label', diag_kind="hist")

# %%
sns.pairplot(df[df['average'] > 0.8][col], hue='label')

# %%
sns.pairplot(df[col].sample(500), hue='label',diag_kind="hist")

# %%
sns.set_theme(style="darkgrid")
g = sns.JointGrid(data=df, x="median", y="kurtosis", hue='label')

g.plot_joint(sns.scatterplot)
g.plot_marginals(sns.kdeplot)

# %%
df.corr()
# Out:
#                                 average    median  ...  kurtosis     label
# average                        1.000000  0.801761  ... -0.009727  0.151117
# median                         0.801761  1.000000  ... -0.210377 -0.405371
# maximum                        0.965296  0.814316  ...  0.017963  0.140811
# minimum                        0.038837  0.017577  ...  0.008549  0.034066
# peak                           0.090119  0.612753  ... -0.265215 -0.742846
# none_levated_peak              0.931401  0.543058  ...  0.104447  0.436227
# sample_standard_deviation      0.990202  0.810740  ...  0.008666  0.154739
# population_standard_deviation  0.990203  0.810740  ...  0.008666  0.154740
# percentile15                   0.779930  0.961343  ... -0.240759 -0.388003
# percentile25                   0.777280  0.976162  ... -0.290815 -0.425553
# percentile50                   0.801761  1.000000  ... -0.210377 -0.405371
# percentile75                   0.817663  0.984380  ... -0.150549 -0.377232
# amplitude                      0.965296  0.814316  ...  0.017963  0.140811
# variance                       0.906192  0.766945  ...  0.049908  0.166247
# interquartile_range            0.819087  0.975010  ... -0.110285 -0.359519
# semi_interquartile_range       0.819087  0.975010  ... -0.110285 -0.359519
# coefficient_of_variation       0.990314  0.802936  ... -0.038623  0.111958
# skewness                      -0.925718 -0.735105  ...  0.076567 -0.081510
# kurtosis                      -0.009727 -0.210377  ...  1.000000  0.439880
# label                          0.151117 -0.405371  ...  0.439880  1.000000
#
# [20 rows x 20 columns]

# %%
plt.figure(figsize=(13,10))
sns.heatmap(df.corr(), vmin=-1, vmax=1, center=0, linewidths=.5, cmap=color_map)
